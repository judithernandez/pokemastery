# %%
from PIL import Image
import numpy as np
import os

# %%
data_directory = os.path.join(os.getcwd(), 'data')
print(data_directory)
# Out:
# /Users/judith/Desktop/code-learn/notebooks/data

# %%
image_path = os.path.join(data_directory, '175.png')
image = Image.open(image_path)
image.resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
image.getbands()
# Out:
# ('R', 'G', 'B')

# %%
image.getpixel((0, 0))
# Out:
# (254, 253, 254)

# %%
image_array = np.array(image)
print(image_array.shape)
# Out:
# (2048, 2048, 3)

# %%
image_path = os.path.join(data_directory, 'images/images/abra.png')
image = Image.open(image_path)
image.size
# Out:
# (120, 120)
